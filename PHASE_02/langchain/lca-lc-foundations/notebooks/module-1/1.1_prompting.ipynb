# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

# as the 1st message was ours (HumanMessage), we're printing the 2nd message (AIMessage)
# thats why we say response['messages'][1].content or we could say response['messages'][-1].content
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon has no government or cities, so it has no capital. In jokes or fiction, people sometimes playfully call the Apollo 11 site “Tranquility Base” a mock capital, but it’s not official.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is called Selene Prime.
#
# Key details:
# - Location: On the sunlit rim of Shackleton Crater, lunar south pole. The city sits along the crater edge, with subterranean hubs beneath the rim for ice mining and life support.
# - Government: The capital serves as the seat of the Lunar Republic under the Crescent Accord, a federation of lunar city-states. Selene Prime houses the central government, courts, and the Republic’s main data vaults.
# - City design: A mix of sealed domes and lava-tube corridors. 3D-printed regolith bricks form bulk infrastructure; transparent glass-ceramic domes cover public spaces. Solar towers and heat pipes weave through the skyline.
# - Economy: Driven by ice mining and water processing, Helium-3 harvesting in shadowed craters, solar energy exchange with Earth and orbital habitats, and high-tech R&D in biotech, materials, and AI for life support.
# - Landmarks:
#   - The Crown Spire: The central government complex and communications hub.
#   - The Mirror Gardens: A biosphere where reflective algae and glassy flora create shimmering, light-fed biomes.
#   - The Helix Library: A double-helix shaped data archive and learning center.
#   - The Echo Forum: An amphitheater carved into a lava-tube wall, renowned for its natural acoustics.
#   - The Borealis Gate: A ceremonial solar gate at the rim, catching near-constant sun.
#   - Moonspire Observatory: Premier telescope array and space-weather lab.
# - Population: Several million residents including scientists, engineers, administrators, and service workers.
# - Transportation: Lunar mag-lev networks, photon rail lines along the rim, subterranean transit tunnels under the crater floor, and zero-g shuttles between sectors. Personal transit often uses tethered pods and airless trams.
# - Culture: A society forged by long days in sunlight and long nights of radio silence. Public art leans into photonics and acoustics; festivals celebrate alignment of Earth, Moon, and Sun; education emphasizes in-situ resource use, orbital diplomacy, and lunar archaeology.
# - Notable vibe: Selene Prime feels like a crystal city carved into a sunlit edge, where every dawn brings solar power, and every night reveals hive-like underground life beneath the ice.
#
# If you’d prefer a different lunar era, location (e.g., a sea of tranquility far side, or a city in a lava-tube network), or a different name for the capital, I can tailor it.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
